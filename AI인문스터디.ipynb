# %% [markdown]
# <a href="https://colab.research.google.com/github/daJarae/DL_Scratch/blob/main/AI%EC%9D%B8%EB%AC%B8%EC%8A%A4%ED%84%B0%EB%94%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data={'name':['AI 영화영상 콘텐츠를 위한 AI 예술 창작 사례 연구','ARTIFICIAL CREATIVITY: A SYNTHETIC APPROACH TO THE STUDY OF CREATIVE BEHAVIOUR','AI 중국 고전시가 창작(시어의 학습과 생성)',
              'Evaluating Image-Inspired Poetry Generation','SeqGAN 모델을 이용한 한국어 시 자동 생성','BACON: Deep-Learning Powered AI for Poetry Generation with Author Linguistic Style Transfer',
              'haiku poetry generation using interactive evolution vs. poem models','artificial intelligence versus maya angelou: experimental evidence that people cannot differentiate AI generated from human-written poetry',
              'artificial intelligence art attitudes and perceptions toward human versus artificial  intelligence artworks',
              'Image Inspired Poetry Generation in XiaoIce','poem generation using transformers and doc2vec embeddings'],
      'year':[21,6,19,19,18,18,17,21,21,18,20],
      'eval':[[0],[3],[0,2],[3],[0],[0],[1],[0],[0],[1],[-1]]}

#-1: 코사인 유사도 기반, 학습 여부 확인
#0: 튜링테스트. 사람들이 구분 못하면 좋은 AI다 (<보편성:사람같은 = 익숙한)
#1,2: 독창성 반영 (진정한 의미의 creativity가 고려되는 것은 여기부터다)
#3: 일일이 전문가가 평가해줄 순 없기 때문에 그걸 대체할 수 있는 수식으로, 더 다양한 기준 반영

# %%
data=pd.DataFrame(data)

# %%
data
# Out:
#                                                  name  year    eval
# 0                      AI 영화영상 콘텐츠를 위한 AI 예술 창작 사례 연구    21     [0]
# 1   ARTIFICIAL CREATIVITY: A SYNTHETIC APPROACH TO...     6     [3]
# 2                           AI 중국 고전시가 창작(시어의 학습과 생성)    19  [0, 2]
# 3         Evaluating Image-Inspired Poetry Generation    19     [3]
# 4                          SeqGAN 모델을 이용한 한국어 시 자동 생성    18     [0]
# 5   BACON: Deep-Learning Powered AI for Poetry Gen...    18     [0]
# 6   haiku poetry generation using interactive evol...    17     [1]
# 7   artificial intelligence versus maya angelou: e...    21     [0]
# 8   artificial intelligence art attitudes and perc...    21     [0]
# 9         Image Inspired Poetry Generation in XiaoIce    18     [1]
# 10  poem generation using transformers and doc2vec...    20    [-1]

# %%
data.sort_values(['year'], ascending=True)
# Out:
#                                                  name  year    eval
# 1   ARTIFICIAL CREATIVITY: A SYNTHETIC APPROACH TO...     6     [3]
# 6   haiku poetry generation using interactive evol...    17     [1]
# 4                          SeqGAN 모델을 이용한 한국어 시 자동 생성    18     [0]
# 5   BACON: Deep-Learning Powered AI for Poetry Gen...    18     [0]
# 9         Image Inspired Poetry Generation in XiaoIce    18     [1]
# 2                           AI 중국 고전시가 창작(시어의 학습과 생성)    19  [0, 2]
# 3         Evaluating Image-Inspired Poetry Generation    19     [3]
# 10  poem generation using transformers and doc2vec...    20    [-1]
# 0                      AI 영화영상 콘텐츠를 위한 AI 예술 창작 사례 연구    21     [0]
# 7   artificial intelligence versus maya angelou: e...    21     [0]
# 8   artificial intelligence art attitudes and perc...    21     [0]

# %% [markdown]
# 문학을 3으로 평가한 논문이 일단 우리가 본것중엔 없다

# %%
data.sort_values(['eval'], ascending=True)
# Out:
#                                                  name  year    eval
# 10  poem generation using transformers and doc2vec...    20    [-1]
# 0                      AI 영화영상 콘텐츠를 위한 AI 예술 창작 사례 연구    21     [0]
# 4                          SeqGAN 모델을 이용한 한국어 시 자동 생성    18     [0]
# 5   BACON: Deep-Learning Powered AI for Poetry Gen...    18     [0]
# 7   artificial intelligence versus maya angelou: e...    21     [0]
# 8   artificial intelligence art attitudes and perc...    21     [0]
# 2                           AI 중국 고전시가 창작(시어의 학습과 생성)    19  [0, 2]
# 6   haiku poetry generation using interactive evol...    17     [1]
# 9         Image Inspired Poetry Generation in XiaoIce    18     [1]
# 1   ARTIFICIAL CREATIVITY: A SYNTHETIC APPROACH TO...     6     [3]
# 3         Evaluating Image-Inspired Poetry Generation    19     [3]
